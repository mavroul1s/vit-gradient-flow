# %% [markdown]
# # Julia Matrix Basics for Vision Models
# This notebook covers the fundamental matrix operations required for building Vision Transformers, including dummy data generation, broadcasting, and matrix multiplication.

# %%
using LinearAlgebra
using Random

# Set a seed for reproducibility
Random.seed!(42)
println("Libraries loaded and random seed set.")
# Out:
# Libraries loaded and random seed set.

# %% [markdown]
# ### 1. Generating Dummy Data
# In computer vision, images are often flattened into patches. Here we create a small 4x4 matrix to represent a dummy sequence of image patches.

# %%
# Create a dummy image patch (a 4x4 matrix of random Float64 values)
X = rand(Float64, 4, 4)

println("Input Matrix X (Dummy Image Patch):")
display(X)
# Out:
# Input Matrix X (Dummy Image Patch):
# 4×4 Matrix{Float64}:
#  0.173575  0.527015  0.980758   0.211228
#  0.321662  0.483022  0.0944314  0.183429
#  0.258585  0.390663  0.544758   0.347508
#  0.166439  0.802763  0.433914   0.622647

# %% [markdown]
# ### 2. Broadcasting (Element-wise Operations)
# To apply an activation function like ReLU, we need to operate on every element individually. In Julia, adding a dot `.` before an operator applies it element-wise.
